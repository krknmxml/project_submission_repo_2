# %%
offset = 0
limit = 3000
period = 'max' # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max

# %%
import pandas as pd

data = pd.read_csv("http://www.nasdaqtrader.com/dynamic/SymDir/nasdaqtraded.txt", sep='|')
data_clean = data[data['Test Issue'] == 'N']
symbols = data_clean['NASDAQ Symbol'].tolist()
print('total number of symbols traded = {}'.format(len(symbols)))
# Out:
# total number of symbols traded = 11263

# %%
data.head()
# Out:
#   Nasdaq Traded Symbol                                      Security Name  \
# 0             Y      A            Agilent Technologies, Inc. Common Stock
# 1             Y     AA                    Alcoa Corporation Common Stock
# 2             Y    AAA  Investment Managers Series Trust II AXS First ...
# 3             Y   AAAU             Goldman Sachs Physical Gold ETF Shares
# 4             Y    AAC  Ares Acquisition Corporation Class A Ordinary ...
#
#   Listing Exchange Market Category ETF  Round Lot Size Test Issue  \
# 0                N                   N           100.0          N
# 1                N                   N           100.0          N
# 2                P                   Y           100.0          N
# 3                Z                   Y           100.0          N
# 4                N                   N           100.0          N
#
#   Financial Status CQS Symbol NASDAQ Symbol NextShares
# 0              NaN          A             A          N
# 1              NaN         AA            AA          N
# 2              NaN        AAA           AAA          N
# 3              NaN       AAAU          AAAU          N
# 4              NaN        AAC           AAC          N

# %%
data.isna().sum()
# Out:
# Nasdaq Traded          0
# Symbol                 2
# Security Name          1
# Listing Exchange       1
# Market Category        1
# ETF                    1
# Round Lot Size         1
# Test Issue             1
# Financial Status    6168
# CQS Symbol          5131
# NASDAQ Symbol          2
# NextShares             1
# dtype: int64

# %%
data.dropna(subset = ["NASDAQ Symbol", "ETF"], inplace=True)

# %%
data.isna().sum()
# Out:
# Nasdaq Traded          0
# Symbol                 0
# Security Name          0
# Listing Exchange       0
# Market Category        0
# ETF                    0
# Round Lot Size         0
# Test Issue             0
# Financial Status    6167
# CQS Symbol          5129
# NASDAQ Symbol          0
# NextShares             0
# dtype: int64

# %%
data.head()
# Out:
# Empty DataFrame
# Columns: [Nasdaq Traded, Symbol, Security Name, Listing Exchange, Market Category, ETF, Round Lot Size, Test Issue, Financial Status, CQS Symbol, NASDAQ Symbol, NextShares]
# Index: []

# %%
import yfinance as yf
import os, contextlib

# %%
# %%time

limit = limit if limit else len(symbols)
end = min(offset + limit, len(symbols))
is_valid = [False] * len(symbols)
# force silencing of verbose API
with open(os.devnull, 'w') as devnull:
    with contextlib.redirect_stdout(devnull):
        for i in range(offset, end):
            s = symbols[i]
            data = yf.download(s, period=period)
            if len(data.index) == 0:
                continue
        
            is_valid[i] = True
            data.to_csv('hist/{}.csv'.format(s))

print('Total number of valid symbols downloaded = {}'.format(sum(is_valid)))
# Out:
# 1 Failed download:
# ['AAC=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AAC+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AACT=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AACT+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AAIC-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AAIC-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AAM-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AAM-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ABR-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ABR-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ABR-F']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ACAQ=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ACAQ+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ACHR+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ACP-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ACR-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ACR-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ACRO=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ACRO+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ADC-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ADEX=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ADEX+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ADRT=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AEL-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AEL-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AEON+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AEVA+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AGM-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AGM-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AGM-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AGM-F']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AGM-G']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AGM.A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AHH-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AHL-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AHL-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AHL-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AHT-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AHT-F']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AHT-G']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AHT-H']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AHT-I']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AIG-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AKO.A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AKO.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AL-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ALL-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ALL-H']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ALL-I']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ALL-J']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ALLG+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ALTG-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ALUR+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AMBI+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AMBP+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AMH-G']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AMH-H']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AMPX+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AP+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['APCA=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['APCA+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['APGB=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['APGB+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['APO-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ARGO-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ARR-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ASB-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ASB-F']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ATAQ=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ATCO-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ATCO-H']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ATCO-I']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ATEK=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ATEK+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ATH-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ATH-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ATH-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ATH-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['ATH-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AUB-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AULT-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['AXS-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BAC-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BAC-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BAC-K']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BAC-L']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BAC-M']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BAC-N']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BAC-O']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BAC-P']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BAC-Q']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BAC-S']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BARK+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BBAI+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BC-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BC-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BC-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BEP-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BF.A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BF.B']: Exception('%ticker%: No price data found, symbol may be delisted (1d 1924-09-16 -> 2023-08-24)')
#
# 1 Failed download:
# ['BFAC=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BFAC+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BFLY+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BFS-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BFS-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BH.A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BHIL+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BHR-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BHR-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BIO.B']: Exception('%ticker%: No price data found, symbol may be delisted (1d 1924-09-16 -> 2023-08-24)')
#
# 1 Failed download:
# ['BIP-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BIP-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BITE=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BITE+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BKKT+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BKSY+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BLUA=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BLUA+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BMAC=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BMAC+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BML-G']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BML-H']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BML-J']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BML-L']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BMTX+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BNIXR']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['BOAC=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BOAC+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BODY+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BOH-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BOWNR']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['BRACR']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['BRD=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BRD+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BRDS+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BREZR']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['BRK.A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BRK.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BRLIR']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['BUJAR']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['BURU+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BW-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BWAQR']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['BYN=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['BYN+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['C-J']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['C-K']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['C-N']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CADE-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CANO+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CCV=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CCV+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CCVI=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CCVI+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CDR-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CDR-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CELG^']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CEQP-']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CETUR']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['CFG-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CFG-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CFR-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CHMI-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CHMI-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CIG.C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CIM-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CIM-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CIM-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CIM-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CIO-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CLDT-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CLOER']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['CLRCR']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['CLVT-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CMRE-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CMRE-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CMRE-D']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CMRE-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CMS-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CMS-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CNDA=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CNDA+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CNDB=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CNDB+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CNFRZ']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['CNO-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CODI-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CODI-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CODI-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['COF-I']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['COF-J']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['COF-K']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['COF-L']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['COF-N']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CORR-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CPTK=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CRD.A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CRD.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CSLMR']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['CSR-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CSTA=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CSTA+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CTA-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CTA-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CTO-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CTOS+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CTV+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CUBI-E']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CUBI-F']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CVE+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CVII=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CVII+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CWEN.A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CXAC=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['CXAC+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['DBRG-H']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['DBRG-I']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['DBRG-J']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['DC+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['DCP-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['DISTR']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['DLNG-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['DLNG-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['DLR-J']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['DLR-K']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['DLR-L']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['DMAQR']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#
# 1 Failed download:
# ['DMYY=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['DMYY+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['DNA+']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['DRH-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['DSAQ=']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['DSX-B']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['DUK-A']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['DX-C']: Exception('%ticker%: No timezone found, symbol may be delisted')
#
# 1 Failed download:
# ['EAI']: Exception('%ticker%: No price data found, symbol may be delisted (1d 1924-09-16 -> 2023-08-24)')
# Total number of valid symbols downloaded = 2764
# CPU times: user 4min 10s, sys: 22.1 s, total: 4min 32s
# Wall time: 19min 24s
